# %% [markdown]
# # INSTALLATION JUPYTER NOTEBOOK

# %% [markdown]
# ## 0. LIBRARIES

# %% [markdown]
# ## Setting up the environment

# %% [markdown]
# I have started a new environment from the anaconda navigator-> environments-> new with python 3.9

# %% [markdown]
# Then install jupyter-lab, to be able to run the following cells.

# %% [markdown]
# ### Libraries installation
# Only run once, once they are installed just import them

# %%
# PIL python image library
# !conda install -c anaconda pillow -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - pillow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.4.26  |       haa95532_0         163 KB  anaconda
#     certifi-2022.6.15          |   py39haa95532_0         157 KB  anaconda
#     libtiff-4.2.0              |       hd0e1b90_0         1.1 MB  anaconda
#     libwebp-1.2.2              |       h2bbff1b_0         1.5 MB  anaconda
#     lz4-c-1.9.3                |       h2bbff1b_1         141 KB  anaconda
#     pillow-9.0.1               |   py39hdc2b20a_0         1.0 MB  anaconda
#     xz-5.2.5                   |       h8cc25b3_1         336 KB  anaconda
#     zstd-1.4.5                 |       h04227a9_0         837 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         5.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   freetype           anaconda/win-64::freetype-2.10.4-hd328e21_0
#   jpeg               anaconda/win-64::jpeg-9b-vc14h4d7706e_1
#   libpng             anaconda/win-64::libpng-1.6.37-h2a8f88b_0
#   libtiff            anaconda/win-64::libtiff-4.2.0-hd0e1b90_0
#   libwebp            anaconda/win-64::libwebp-1.2.2-h2bbff1b_0
#   lz4-c              anaconda/win-64::lz4-c-1.9.3-h2bbff1b_1
#   pillow             anaconda/win-64::pillow-9.0.1-py39hdc2b20a_0
#   tk                 anaconda/win-64::tk-8.6.7-vc14hb68737d_1
#   xz                 anaconda/win-64::xz-5.2.5-h8cc25b3_1
#   zlib               anaconda/win-64::zlib-1.2.11-vc14h1cdd9ab_1
#   zstd               anaconda/win-64::zstd-1.4.5-h04227a9_0
#
# The following packages will be UPDATED:
#
#   openssl            conda-forge::openssl-1.1.1q-h8ffe710_0 --> pkgs/main::openssl-1.1.1s-h2bbff1b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.9.2~ --> anaconda::ca-certificates-2022.4.26-haa95532_0
#   certifi            conda-forge/noarch::certifi-2022.9.24~ --> anaconda/win-64::certifi-2022.6.15-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2022 | 163 KB    |            |   0%
# ca-certificates-2022 | 163 KB    | 9          |  10%
# ca-certificates-2022 | 163 KB    | ########## | 100%
#
# libtiff-4.2.0        | 1.1 MB    |            |   0%
# libtiff-4.2.0        | 1.1 MB    | ####5      |  46%
# libtiff-4.2.0        | 1.1 MB    | ########## | 100%
# libtiff-4.2.0        | 1.1 MB    | ########## | 100%
#
# zstd-1.4.5           | 837 KB    |            |   0%
# zstd-1.4.5           | 837 KB    | 1          |   2%
# zstd-1.4.5           | 837 KB    | #5         |  15%
# zstd-1.4.5           | 837 KB    | ###        |  31%
# zstd-1.4.5           | 837 KB    | #####7     |  57%
# zstd-1.4.5           | 837 KB    | ########4  |  84%
# zstd-1.4.5           | 837 KB    | ########## | 100%
#
# xz-5.2.5             | 336 KB    |            |   0%
# xz-5.2.5             | 336 KB    | 4          |   5%
# xz-5.2.5             | 336 KB    | ########## | 100%
#
# lz4-c-1.9.3          | 141 KB    |            |   0%
# lz4-c-1.9.3          | 141 KB    | #1         |  11%
# lz4-c-1.9.3          | 141 KB    | ########## | 100%
# lz4-c-1.9.3          | 141 KB    | ########## | 100%
#
# certifi-2022.6.15    | 157 KB    |            |   0%
# certifi-2022.6.15    | 157 KB    | ########## | 100%
#
# pillow-9.0.1         | 1.0 MB    |            |   0%
# pillow-9.0.1         | 1.0 MB    | 1          |   2%
# pillow-9.0.1         | 1.0 MB    | #########4 |  94%
# pillow-9.0.1         | 1.0 MB    | ########## | 100%
#
# libwebp-1.2.2        | 1.5 MB    |            |   0%
# libwebp-1.2.2        | 1.5 MB    | 1          |   1%
# libwebp-1.2.2        | 1.5 MB    | 8          |   8%
# libwebp-1.2.2        | 1.5 MB    | ##         |  21%
# libwebp-1.2.2        | 1.5 MB    | ###1       |  32%
# libwebp-1.2.2        | 1.5 MB    | ####3      |  43%
# libwebp-1.2.2        | 1.5 MB    | ######3    |  64%
# libwebp-1.2.2        | 1.5 MB    | ########   |  80%
# libwebp-1.2.2        | 1.5 MB    | ########## | 100%
# libwebp-1.2.2        | 1.5 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# pathlib Paths library
# !conda install -c anaconda pathlib -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - pathlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pathlib-1.0.1              |     pyhd3eb1b0_1          17 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:          17 KB
#
# The following NEW packages will be INSTALLED:
#
#   pathlib            anaconda/noarch::pathlib-1.0.1-pyhd3eb1b0_1
#
#
#
# Downloading and Extracting Packages
#
# pathlib-1.0.1        | 17 KB     |            |   0%
# pathlib-1.0.1        | 17 KB     | #########5 |  96%
# pathlib-1.0.1        | 17 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# pandas Data tables management
# !conda install pandas -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.5           |   py39h080aedc_0         117 KB
#     numexpr-2.8.4              |   py39h5b0cc5e_0         127 KB
#     numpy-1.23.4               |   py39h3b20f71_0          10 KB
#     numpy-base-1.23.4          |   py39h4da318b_0         6.3 MB
#     pandas-1.5.1               |   py39hf11a4ad_0        11.5 MB
#     ------------------------------------------------------------
#                                            Total:        18.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   bottleneck         pkgs/main/win-64::bottleneck-1.3.5-py39h080aedc_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2021.4.0-haa95532_3556
#   mkl                pkgs/main/win-64::mkl-2021.4.0-haa95532_640
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py39h2bbff1b_0
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.1-py39h277e83a_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.2-py39hf11a4ad_0
#   numexpr            pkgs/main/win-64::numexpr-2.8.4-py39h5b0cc5e_0
#   numpy              pkgs/main/win-64::numpy-1.23.4-py39h3b20f71_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.23.4-py39h4da318b_0
#   pandas             pkgs/main/win-64::pandas-1.5.1-py39hf11a4ad_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> pkgs/main::ca-certificates-2022.10.11-haa95532_0
#   certifi            anaconda::certifi-2022.6.15-py39haa95~ --> pkgs/main::certifi-2022.9.24-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# numexpr-2.8.4        | 127 KB    |            |   0%
# numexpr-2.8.4        | 127 KB    | #2         |  13%
# numexpr-2.8.4        | 127 KB    | ########## | 100%
#
# pandas-1.5.1         | 11.5 MB   |            |   0%
# pandas-1.5.1         | 11.5 MB   |            |   0%
# pandas-1.5.1         | 11.5 MB   | #3         |  13%
# pandas-1.5.1         | 11.5 MB   | ###6       |  36%
# pandas-1.5.1         | 11.5 MB   | #####4     |  55%
# pandas-1.5.1         | 11.5 MB   | #######7   |  77%
# pandas-1.5.1         | 11.5 MB   | #########7 |  98%
# pandas-1.5.1         | 11.5 MB   | ########## | 100%
#
# numpy-base-1.23.4    | 6.3 MB    |            |   0%
# numpy-base-1.23.4    | 6.3 MB    |            |   0%
# numpy-base-1.23.4    | 6.3 MB    | 3          |   3%
# numpy-base-1.23.4    | 6.3 MB    | 6          |   6%
# numpy-base-1.23.4    | 6.3 MB    | #2         |  12%
# numpy-base-1.23.4    | 6.3 MB    | #6         |  17%
# numpy-base-1.23.4    | 6.3 MB    | ##3        |  23%
# numpy-base-1.23.4    | 6.3 MB    | ###        |  30%
# numpy-base-1.23.4    | 6.3 MB    | ###5       |  35%
# numpy-base-1.23.4    | 6.3 MB    | ####       |  41%
# numpy-base-1.23.4    | 6.3 MB    | ####6      |  47%
# numpy-base-1.23.4    | 6.3 MB    | #####2     |  52%
# numpy-base-1.23.4    | 6.3 MB    | #####7     |  58%
# numpy-base-1.23.4    | 6.3 MB    | ######2    |  63%
# numpy-base-1.23.4    | 6.3 MB    | ######9    |  70%
# numpy-base-1.23.4    | 6.3 MB    | #######6   |  76%
# numpy-base-1.23.4    | 6.3 MB    | ########9  |  89%
# numpy-base-1.23.4    | 6.3 MB    | ########## | 100%
# numpy-base-1.23.4    | 6.3 MB    | ########## | 100%
#
# numpy-1.23.4         | 10 KB     |            |   0%
# numpy-1.23.4         | 10 KB     | ########## | 100%
# numpy-1.23.4         | 10 KB     | ########## | 100%
#
# bottleneck-1.3.5     | 117 KB    |            |   0%
# bottleneck-1.3.5     | 117 KB    | #3         |  14%
# bottleneck-1.3.5     | 117 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# scikit-image Image processing library
# !conda install -c anaconda scikit-image -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - scikit-image
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blosc-1.21.0               |       h19a0ad4_0         164 KB  anaconda
#     brotli-1.0.9               |       ha925a31_2         894 KB  anaconda
#     bzip2-1.0.8                |       he774522_0         150 KB  anaconda
#     charls-2.2.0               |       h6c2663c_0          93 KB  anaconda
#     cloudpickle-2.0.0          |     pyhd3eb1b0_0          31 KB  anaconda
#     cytoolz-0.11.0             |   py39h2bbff1b_0         346 KB  anaconda
#     dask-core-2.16.0           |             py_0         610 KB  anaconda
#     giflib-5.2.1               |       h62dcd97_0          87 KB  anaconda
#     imagecodecs-2021.4.28      |   py39h5da4933_0         6.9 MB  anaconda
#     imageio-2.9.0              |     pyhd3eb1b0_0         3.1 MB  anaconda
#     lcms2-2.12                 |       h83e58a3_0         884 KB  anaconda
#     lerc-2.2.1                 |       hd77b12b_0         134 KB  anaconda
#     libaec-1.0.4               |       h33f27b4_1          33 KB  anaconda
#     libdeflate-1.7             |       h2bbff1b_5          64 KB  anaconda
#     libzopfli-1.0.3            |       ha925a31_0         206 KB  anaconda
#     networkx-2.7.1             |     pyhd3eb1b0_0         1.5 MB  anaconda
#     openjpeg-2.4.0             |       h4fc8c34_0         243 KB  anaconda
#     pywavelets-1.3.0           |   py39h2bbff1b_0         4.3 MB  anaconda
#     scikit-image-0.19.2        |   py39hf11a4ad_0        11.2 MB  anaconda
#     scipy-1.7.3                |   py39h0a974cb_0        17.9 MB  anaconda
#     snappy-1.1.9               |       h6c2663c_0         6.2 MB  anaconda
#     tifffile-2021.7.2          |     pyhd3eb1b0_2         133 KB  anaconda
#     toolz-0.11.2               |     pyhd3eb1b0_0          48 KB  anaconda
#     zfp-0.5.5                  |       hd77b12b_6         164 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        55.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   blosc              anaconda/win-64::blosc-1.21.0-h19a0ad4_0
#   brotli             anaconda/win-64::brotli-1.0.9-ha925a31_2
#   bzip2              anaconda/win-64::bzip2-1.0.8-he774522_0
#   charls             anaconda/win-64::charls-2.2.0-h6c2663c_0
#   cloudpickle        anaconda/noarch::cloudpickle-2.0.0-pyhd3eb1b0_0
#   cytoolz            anaconda/win-64::cytoolz-0.11.0-py39h2bbff1b_0
#   dask-core          anaconda/noarch::dask-core-2.16.0-py_0
#   giflib             anaconda/win-64::giflib-5.2.1-h62dcd97_0
#   icc_rt             anaconda/win-64::icc_rt-2019.0.0-h0cc432a_1
#   imagecodecs        anaconda/win-64::imagecodecs-2021.4.28-py39h5da4933_0
#   imageio            anaconda/noarch::imageio-2.9.0-pyhd3eb1b0_0
#   lcms2              anaconda/win-64::lcms2-2.12-h83e58a3_0
#   lerc               anaconda/win-64::lerc-2.2.1-hd77b12b_0
#   libaec             anaconda/win-64::libaec-1.0.4-h33f27b4_1
#   libdeflate         anaconda/win-64::libdeflate-1.7-h2bbff1b_5
#   libzopfli          anaconda/win-64::libzopfli-1.0.3-ha925a31_0
#   networkx           anaconda/noarch::networkx-2.7.1-pyhd3eb1b0_0
#   openjpeg           anaconda/win-64::openjpeg-2.4.0-h4fc8c34_0
#   pywavelets         anaconda/win-64::pywavelets-1.3.0-py39h2bbff1b_0
#   scikit-image       anaconda/win-64::scikit-image-0.19.2-py39hf11a4ad_0
#   scipy              anaconda/win-64::scipy-1.7.3-py39h0a974cb_0
#   snappy             anaconda/win-64::snappy-1.1.9-h6c2663c_0
#   tifffile           anaconda/noarch::tifffile-2021.7.2-pyhd3eb1b0_2
#   toolz              anaconda/noarch::toolz-0.11.2-pyhd3eb1b0_0
#   zfp                anaconda/win-64::zfp-0.5.5-hd77b12b_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> anaconda::ca-certificates-2022.4.26-haa95532_0
#   certifi            pkgs/main::certifi-2022.9.24-py39haa9~ --> anaconda::certifi-2022.6.15-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# openjpeg-2.4.0       | 243 KB    |            |   0%
# openjpeg-2.4.0       | 243 KB    | 6          |   7%
# openjpeg-2.4.0       | 243 KB    | ########## | 100%
# openjpeg-2.4.0       | 243 KB    | ########## | 100%
#
# libdeflate-1.7       | 64 KB     |            |   0%
# libdeflate-1.7       | 64 KB     | ##4        |  25%
# libdeflate-1.7       | 64 KB     | ########## | 100%
#
# lcms2-2.12           | 884 KB    |            |   0%
# lcms2-2.12           | 884 KB    | 1          |   2%
# lcms2-2.12           | 884 KB    | #4         |  14%
# lcms2-2.12           | 884 KB    | ####3      |  43%
# lcms2-2.12           | 884 KB    | ########## | 100%
# lcms2-2.12           | 884 KB    | ########## | 100%
#
# libaec-1.0.4         | 33 KB     |            |   0%
# libaec-1.0.4         | 33 KB     | ####7      |  48%
# libaec-1.0.4         | 33 KB     | ########## | 100%
#
# snappy-1.1.9         | 6.2 MB    |            |   0%
# snappy-1.1.9         | 6.2 MB    |            |   0%
# snappy-1.1.9         | 6.2 MB    | 6          |   6%
# snappy-1.1.9         | 6.2 MB    | ##         |  21%
# snappy-1.1.9         | 6.2 MB    | #####3     |  54%
# snappy-1.1.9         | 6.2 MB    | #########6 |  96%
# snappy-1.1.9         | 6.2 MB    | ########## | 100%
#
# dask-core-2.16.0     | 610 KB    |            |   0%
# dask-core-2.16.0     | 610 KB    | 2          |   3%
# dask-core-2.16.0     | 610 KB    | ########## | 100%
# dask-core-2.16.0     | 610 KB    | ########## | 100%
#
# lerc-2.2.1           | 134 KB    |            |   0%
# lerc-2.2.1           | 134 KB    | #1         |  12%
# lerc-2.2.1           | 134 KB    | ########## | 100%
# lerc-2.2.1           | 134 KB    | ########## | 100%
#
# scipy-1.7.3          | 17.9 MB   |            |   0%
# scipy-1.7.3          | 17.9 MB   |            |   0%
# scipy-1.7.3          | 17.9 MB   | #7         |  17%
# scipy-1.7.3          | 17.9 MB   | ###7       |  38%
# scipy-1.7.3          | 17.9 MB   | #####8     |  58%
# scipy-1.7.3          | 17.9 MB   | #######9   |  79%
# scipy-1.7.3          | 17.9 MB   | #########7 |  97%
# scipy-1.7.3          | 17.9 MB   | ########## | 100%
#
# pywavelets-1.3.0     | 4.3 MB    |            |   0%
# pywavelets-1.3.0     | 4.3 MB    |            |   0%
# pywavelets-1.3.0     | 4.3 MB    | 3          |   4%
# pywavelets-1.3.0     | 4.3 MB    | 7          |   7%
# pywavelets-1.3.0     | 4.3 MB    | #2         |  12%
# pywavelets-1.3.0     | 4.3 MB    | #6         |  16%
# pywavelets-1.3.0     | 4.3 MB    | ##1        |  21%
# pywavelets-1.3.0     | 4.3 MB    | ##6        |  26%
# pywavelets-1.3.0     | 4.3 MB    | ###        |  30%
# pywavelets-1.3.0     | 4.3 MB    | ###5       |  35%
# pywavelets-1.3.0     | 4.3 MB    | ###9       |  40%
# pywavelets-1.3.0     | 4.3 MB    | ####3      |  44%
# pywavelets-1.3.0     | 4.3 MB    | ####9      |  49%
# pywavelets-1.3.0     | 4.3 MB    | #####4     |  54%
# pywavelets-1.3.0     | 4.3 MB    | #####8     |  59%
# pywavelets-1.3.0     | 4.3 MB    | ######3    |  64%
# pywavelets-1.3.0     | 4.3 MB    | ######8    |  68%
# pywavelets-1.3.0     | 4.3 MB    | #######3   |  73%
# pywavelets-1.3.0     | 4.3 MB    | #######7   |  78%
# pywavelets-1.3.0     | 4.3 MB    | ########4  |  84%
# pywavelets-1.3.0     | 4.3 MB    | #########  |  90%
# pywavelets-1.3.0     | 4.3 MB    | #########5 |  96%
# pywavelets-1.3.0     | 4.3 MB    | ########## | 100%
#
# blosc-1.21.0         | 164 KB    |            |   0%
# blosc-1.21.0         | 164 KB    | 9          |  10%
# blosc-1.21.0         | 164 KB    | ########## | 100%
#
# cytoolz-0.11.0       | 346 KB    |            |   0%
# cytoolz-0.11.0       | 346 KB    | 4          |   5%
# cytoolz-0.11.0       | 346 KB    | ###7       |  37%
# cytoolz-0.11.0       | 346 KB    | ######4    |  65%
# cytoolz-0.11.0       | 346 KB    | ########## | 100%
# cytoolz-0.11.0       | 346 KB    | ########## | 100%
#
# imagecodecs-2021.4.2 | 6.9 MB    |            |   0%
# imagecodecs-2021.4.2 | 6.9 MB    |            |   0%
# imagecodecs-2021.4.2 | 6.9 MB    | 1          |   2%
# imagecodecs-2021.4.2 | 6.9 MB    | 5          |   5%
# imagecodecs-2021.4.2 | 6.9 MB    | #5         |  15%
# imagecodecs-2021.4.2 | 6.9 MB    | ###7       |  38%
# imagecodecs-2021.4.2 | 6.9 MB    | #######5   |  75%
# imagecodecs-2021.4.2 | 6.9 MB    | ########## | 100%
# imagecodecs-2021.4.2 | 6.9 MB    | ########## | 100%
#
# brotli-1.0.9         | 894 KB    |            |   0%
# brotli-1.0.9         | 894 KB    | 1          |   2%
# brotli-1.0.9         | 894 KB    | #4         |  14%
# brotli-1.0.9         | 894 KB    | ###2       |  32%
# brotli-1.0.9         | 894 KB    | #####7     |  57%
# brotli-1.0.9         | 894 KB    | ########## | 100%
# brotli-1.0.9         | 894 KB    | ########## | 100%
#
# bzip2-1.0.8          | 150 KB    |            |   0%
# bzip2-1.0.8          | 150 KB    | #          |  11%
# bzip2-1.0.8          | 150 KB    | ########## | 100%
#
# zfp-0.5.5            | 164 KB    |            |   0%
# zfp-0.5.5            | 164 KB    | 9          |  10%
# zfp-0.5.5            | 164 KB    | ########## | 100%
#
# networkx-2.7.1       | 1.5 MB    |            |   0%
# networkx-2.7.1       | 1.5 MB    | 1          |   1%
# networkx-2.7.1       | 1.5 MB    | 8          |   8%
# networkx-2.7.1       | 1.5 MB    | ##         |  20%
# networkx-2.7.1       | 1.5 MB    | ###2       |  33%
# networkx-2.7.1       | 1.5 MB    | ####4      |  45%
# networkx-2.7.1       | 1.5 MB    | #####5     |  55%
# networkx-2.7.1       | 1.5 MB    | #######1   |  71%
# networkx-2.7.1       | 1.5 MB    | ########5  |  86%
# networkx-2.7.1       | 1.5 MB    | ########## | 100%
# networkx-2.7.1       | 1.5 MB    | ########## | 100%
#
# tifffile-2021.7.2    | 133 KB    |            |   0%
# tifffile-2021.7.2    | 133 KB    | #2         |  12%
# tifffile-2021.7.2    | 133 KB    | ########## | 100%
#
# giflib-5.2.1         | 87 KB     |            |   0%
# giflib-5.2.1         | 87 KB     | #8         |  18%
# giflib-5.2.1         | 87 KB     | ########## | 100%
#
# imageio-2.9.0        | 3.1 MB    |            |   0%
# imageio-2.9.0        | 3.1 MB    |            |   1%
# imageio-2.9.0        | 3.1 MB    | #4         |  15%
# imageio-2.9.0        | 3.1 MB    | ####5      |  45%
# imageio-2.9.0        | 3.1 MB    | ########9  |  90%
# imageio-2.9.0        | 3.1 MB    | ########## | 100%
#
# libzopfli-1.0.3      | 206 KB    |            |   0%
# libzopfli-1.0.3      | 206 KB    | 7          |   8%
# libzopfli-1.0.3      | 206 KB    | ########## | 100%
#
# charls-2.2.0         | 93 KB     |            |   0%
# charls-2.2.0         | 93 KB     | #7         |  17%
# charls-2.2.0         | 93 KB     | ########## | 100%
#
# toolz-0.11.2         | 48 KB     |            |   0%
# toolz-0.11.2         | 48 KB     | ########## | 100%
#
# cloudpickle-2.0.0    | 31 KB     |            |   0%
# cloudpickle-2.0.0    | 31 KB     | #####1     |  51%
# cloudpickle-2.0.0    | 31 KB     | ########## | 100%
#
# scikit-image-0.19.2  | 11.2 MB   |            |   0%
# scikit-image-0.19.2  | 11.2 MB   |            |   0%
# scikit-image-0.19.2  | 11.2 MB   | ##8        |  28%
# scikit-image-0.19.2  | 11.2 MB   | #####5     |  55%
# scikit-image-0.19.2  | 11.2 MB   | #######6   |  76%
# scikit-image-0.19.2  | 11.2 MB   | #########6 |  96%
# scikit-image-0.19.2  | 11.2 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# os  Operative System management 
# !conda install -c jmcmurray os -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - os
#
#
# The following NEW packages will be INSTALLED:
#
#   os                 jmcmurray/noarch::os-0.1.4-0
#   qutil              jmcmurray/noarch::qutil-3.2.1-6
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> pkgs/main::ca-certificates-2022.10.11-haa95532_0
#   certifi            anaconda::certifi-2022.6.15-py39haa95~ --> pkgs/main::certifi-2022.9.24-py39haa95532_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
## Optional (but useful for future tutorial)
# !conda install -c conda-forge scikit-learn -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.2.0               |     pyhd8ed1ab_0         205 KB  conda-forge
#     libblas-3.9.0              |1_h8933c1f_netlib         193 KB  conda-forge
#     libcblas-3.9.0             |5_hd5c7e75_netlib          95 KB  conda-forge
#     scikit-learn-1.1.2         |   py39hfd4428b_0         7.6 MB  conda-forge
#     threadpoolctl-3.1.0        |     pyh8a188c0_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.2.0-pyhd8ed1ab_0
#   libblas            conda-forge/win-64::libblas-3.9.0-1_h8933c1f_netlib
#   libcblas           conda-forge/win-64::libcblas-3.9.0-5_hd5c7e75_netlib
#   scikit-learn       conda-forge/win-64::scikit-learn-1.1.2-py39hfd4428b_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.1.0-pyh8a188c0_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> conda-forge::ca-certificates-2022.9.24-h5b45459_0
#   certifi            pkgs/main/win-64::certifi-2022.9.24-p~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1s-h2bbff1b_0 --> conda-forge::openssl-1.1.1q-h8ffe710_0
#
#
#
# Downloading and Extracting Packages
#
# scikit-learn-1.1.2   | 7.6 MB    |            |   0%
# scikit-learn-1.1.2   | 7.6 MB    |            |   0%
# scikit-learn-1.1.2   | 7.6 MB    | 4          |   4%
# scikit-learn-1.1.2   | 7.6 MB    | #2         |  13%
# scikit-learn-1.1.2   | 7.6 MB    | #7         |  18%
# scikit-learn-1.1.2   | 7.6 MB    | ####3      |  44%
# scikit-learn-1.1.2   | 7.6 MB    | ########   |  80%
# scikit-learn-1.1.2   | 7.6 MB    | ########## | 100%
#
# threadpoolctl-3.1.0  | 18 KB     |            |   0%
# threadpoolctl-3.1.0  | 18 KB     | ########## | 100%
#
# libcblas-3.9.0       | 95 KB     |            |   0%
# libcblas-3.9.0       | 95 KB     | #6         |  17%
# libcblas-3.9.0       | 95 KB     | ########## | 100%
#
# libblas-3.9.0        | 193 KB    |            |   0%
# libblas-3.9.0        | 193 KB    | 8          |   8%
# libblas-3.9.0        | 193 KB    | ########## | 100%
#
# joblib-1.2.0         | 205 KB    |            |   0%
# joblib-1.2.0         | 205 KB    | ########## | 100%
# joblib-1.2.0         | 205 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
## Napari visualization library (optional but come on give it a try)
# Need to run on command line 
# !conda install -c conda-forge napari -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - napari
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.4.3                |     pyhd8ed1ab_3        13.3 MB  conda-forge
#     click-8.1.3                | win_pyhd8ed1ab_2          75 KB  conda-forge
#     commonmark-0.9.1           |             py_0          46 KB  conda-forge
#     dask-2022.6.1              |     pyhd8ed1ab_0           5 KB  conda-forge
#     dask-core-2022.6.1         |     pyhd8ed1ab_0         838 KB  conda-forge
#     distributed-2022.6.1       |     pyhd8ed1ab_0         731 KB  conda-forge
#     docutils-0.19              |   py39hcbf5309_1         799 KB  conda-forge
#     fasteners-0.17.3           |     pyhd8ed1ab_0          20 KB  conda-forge
#     freetype-py-2.3.0          |     pyhd8ed1ab_0          58 KB  conda-forge
#     fsspec-2022.11.0           |     pyhd8ed1ab_0          96 KB  conda-forge
#     future-0.18.2              |     pyhd8ed1ab_6         356 KB  conda-forge
#     imagesize-1.4.1            |     pyhd8ed1ab_0          10 KB  conda-forge
#     kiwisolver-1.4.4           |   py39h2e07f2f_0          61 KB  conda-forge
#     locket-1.0.0               |     pyhd8ed1ab_0           8 KB  conda-forge
#     lz4-4.0.0                  |   py39h0878066_2          80 KB  conda-forge
#     magicgui-0.6.0             |     pyhd8ed1ab_0          80 KB  conda-forge
#     msgpack-python-1.0.4       |   py39h2e07f2f_0          75 KB  conda-forge
#     napari-0.4.14              |     pyhd8ed1ab_0         1.9 MB  conda-forge
#     napari-console-0.0.6       |     pyhd8ed1ab_0          11 KB  conda-forge
#     napari-svg-0.1.6           |     pyhd8ed1ab_0          15 KB  conda-forge
#     npe2-0.6.1                 |     pyhd8ed1ab_1          63 KB  conda-forge
#     numcodecs-0.10.2           |   py39h415ef7b_0         548 KB  conda-forge
#     numpydoc-1.5.0             |     pyhd8ed1ab_0          46 KB  conda-forge
#     partd-1.3.0                |     pyhd8ed1ab_0          18 KB  conda-forge
#     pep517-0.13.0              |     pyhd8ed1ab_0          19 KB  conda-forge
#     pint-0.20.1                |     pyhd8ed1ab_0         207 KB  conda-forge
#     pooch-1.6.0                |     pyhd8ed1ab_0          44 KB  conda-forge
#     psygnal-0.3.5              |   py39h2e07f2f_0         515 KB  conda-forge
#     pydantic-1.9.2             |   py39hb82d6ee_0         1.6 MB  conda-forge
#     pyopengl-3.1.6             |     pyhd8ed1ab_1         867 KB  conda-forge
#     pyqt-5.9.2                 |   py39hd77b12b_6         4.3 MB
#     python-build-0.9.0         |     pyhd8ed1ab_0          20 KB  conda-forge
#     pytomlpp-1.0.9             |   py39h2e07f2f_0         162 KB  conda-forge
#     pyyaml-6.0                 |   py39hb82d6ee_4         154 KB  conda-forge
#     qtconsole-base-5.4.0       |     pyha770c72_0          91 KB  conda-forge
#     qtpy-2.3.0                 |     pyhd8ed1ab_0          50 KB  conda-forge
#     rich-12.6.0                |     pyhd8ed1ab_0         170 KB  conda-forge
#     shellingham-1.5.0          |     pyhd8ed1ab_0          12 KB  conda-forge
#     sip-4.19.13                |   py39hd77b12b_0         283 KB
#     sphinx-5.3.0               |     pyhd8ed1ab_0         1.6 MB  conda-forge
#     sphinxcontrib-serializinghtml-1.1.5|     pyhd8ed1ab_2          27 KB  conda-forge
#     superqt-0.4.0              |     pyhd8ed1ab_0          52 KB  conda-forge
#     tqdm-4.64.1                |     pyhd8ed1ab_0          82 KB  conda-forge
#     typer-0.7.0                |     pyhd8ed1ab_0          56 KB  conda-forge
#     typing-extensions-4.4.0    |       hd8ed1ab_0           8 KB  conda-forge
#     vispy-0.9.6                |   py39h5d4886f_1         1.6 MB  conda-forge
#     wrapt-1.14.1               |   py39hb82d6ee_0          49 KB  conda-forge
#     yaml-0.2.5                 |       h8ffe710_2          62 KB  conda-forge
#     zarr-2.13.3                |     pyhd8ed1ab_0         141 KB  conda-forge
#     zict-2.2.0                 |     pyhd8ed1ab_0          20 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        31.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   alabaster          conda-forge/noarch::alabaster-0.7.12-py_0
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   asciitree          conda-forge/noarch::asciitree-0.3.3-py_2
#   bokeh              conda-forge/noarch::bokeh-2.4.3-pyhd8ed1ab_3
#   cachey             conda-forge/noarch::cachey-0.2.1-pyh9f0ad1d_0
#   click              conda-forge/noarch::click-8.1.3-win_pyhd8ed1ab_2
#   commonmark         conda-forge/noarch::commonmark-0.9.1-py_0
#   dask               conda-forge/noarch::dask-2022.6.1-pyhd8ed1ab_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   distributed        conda-forge/noarch::distributed-2022.6.1-pyhd8ed1ab_0
#   docstring_parser   conda-forge/noarch::docstring_parser-0.13-pyhd8ed1ab_0
#   docutils           conda-forge/win-64::docutils-0.19-py39hcbf5309_1
#   fasteners          conda-forge/noarch::fasteners-0.17.3-pyhd8ed1ab_0
#   freetype-py        conda-forge/noarch::freetype-py-2.3.0-pyhd8ed1ab_0
#   fsspec             conda-forge/noarch::fsspec-2022.11.0-pyhd8ed1ab_0
#   future             conda-forge/noarch::future-0.18.2-pyhd8ed1ab_6
#   heapdict           conda-forge/noarch::heapdict-1.0.1-py_0
#   hsluv              conda-forge/noarch::hsluv-5.0.2-pyh44b312d_0
#   icu                pkgs/main/win-64::icu-58.2-ha925a31_3
#   imagesize          conda-forge/noarch::imagesize-1.4.1-pyhd8ed1ab_0
#   kiwisolver         conda-forge/win-64::kiwisolver-1.4.4-py39h2e07f2f_0
#   locket             conda-forge/noarch::locket-1.0.0-pyhd8ed1ab_0
#   lz4                conda-forge/win-64::lz4-4.0.0-py39h0878066_2
#   magicgui           conda-forge/noarch::magicgui-0.6.0-pyhd8ed1ab_0
#   msgpack-python     conda-forge/win-64::msgpack-python-1.0.4-py39h2e07f2f_0
#   napari             conda-forge/noarch::napari-0.4.14-pyhd8ed1ab_0
#   napari-console     conda-forge/noarch::napari-console-0.0.6-pyhd8ed1ab_0
#   napari-plugin-eng~ conda-forge/noarch::napari-plugin-engine-0.2.0-pyhd8ed1ab_2
#   napari-svg         conda-forge/noarch::napari-svg-0.1.6-pyhd8ed1ab_0
#   npe2               conda-forge/noarch::npe2-0.6.1-pyhd8ed1ab_1
#   numcodecs          conda-forge/win-64::numcodecs-0.10.2-py39h415ef7b_0
#   numpydoc           conda-forge/noarch::numpydoc-1.5.0-pyhd8ed1ab_0
#   partd              conda-forge/noarch::partd-1.3.0-pyhd8ed1ab_0
#   pep517             conda-forge/noarch::pep517-0.13.0-pyhd8ed1ab_0
#   pint               conda-forge/noarch::pint-0.20.1-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.6.0-pyhd8ed1ab_0
#   psygnal            conda-forge/win-64::psygnal-0.3.5-py39h2e07f2f_0
#   pydantic           conda-forge/win-64::pydantic-1.9.2-py39hb82d6ee_0
#   pyopengl           conda-forge/noarch::pyopengl-3.1.6-pyhd8ed1ab_1
#   pyqt               pkgs/main/win-64::pyqt-5.9.2-py39hd77b12b_6
#   python-build       conda-forge/noarch::python-build-0.9.0-pyhd8ed1ab_0
#   pytomlpp           conda-forge/win-64::pytomlpp-1.0.9-py39h2e07f2f_0
#   pyyaml             conda-forge/win-64::pyyaml-6.0-py39hb82d6ee_4
#   qt                 pkgs/main/win-64::qt-5.9.7-vc14h73c81de_0
#   qtconsole-base     conda-forge/noarch::qtconsole-base-5.4.0-pyha770c72_0
#   qtpy               conda-forge/noarch::qtpy-2.3.0-pyhd8ed1ab_0
#   rich               conda-forge/noarch::rich-12.6.0-pyhd8ed1ab_0
#   shellingham        conda-forge/noarch::shellingham-1.5.0-pyhd8ed1ab_0
#   sip                pkgs/main/win-64::sip-4.19.13-py39hd77b12b_0
#   snowballstemmer    conda-forge/noarch::snowballstemmer-2.2.0-pyhd8ed1ab_0
#   sortedcontainers   conda-forge/noarch::sortedcontainers-2.4.0-pyhd8ed1ab_0
#   sphinx             conda-forge/noarch::sphinx-5.3.0-pyhd8ed1ab_0
#   sphinxcontrib-app~ conda-forge/noarch::sphinxcontrib-applehelp-1.0.2-py_0
#   sphinxcontrib-dev~ conda-forge/noarch::sphinxcontrib-devhelp-1.0.2-py_0
#   sphinxcontrib-htm~ conda-forge/noarch::sphinxcontrib-htmlhelp-2.0.0-pyhd8ed1ab_0
#   sphinxcontrib-jsm~ conda-forge/noarch::sphinxcontrib-jsmath-1.0.1-py_0
#   sphinxcontrib-qth~ conda-forge/noarch::sphinxcontrib-qthelp-1.0.3-py_0
#   sphinxcontrib-ser~ conda-forge/noarch::sphinxcontrib-serializinghtml-1.1.5-pyhd8ed1ab_2
#   superqt            conda-forge/noarch::superqt-0.4.0-pyhd8ed1ab_0
#   tblib              conda-forge/noarch::tblib-1.7.0-pyhd8ed1ab_0
#   tqdm               conda-forge/noarch::tqdm-4.64.1-pyhd8ed1ab_0
#   typer              conda-forge/noarch::typer-0.7.0-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.4.0-hd8ed1ab_0
#   vispy              conda-forge/win-64::vispy-0.9.6-py39h5d4886f_1
#   wrapt              conda-forge/win-64::wrapt-1.14.1-py39hb82d6ee_0
#   yaml               conda-forge/win-64::yaml-0.2.5-h8ffe710_2
#   zarr               conda-forge/noarch::zarr-2.13.3-pyhd8ed1ab_0
#   zict               conda-forge/noarch::zict-2.2.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   dask-core                 anaconda::dask-core-2.16.0-py_0 --> conda-forge::dask-core-2022.6.1-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# tqdm-4.64.1          | 82 KB     |            |   0%
# tqdm-4.64.1          | 82 KB     | #9         |  20%
# tqdm-4.64.1          | 82 KB     | ########## | 100%
#
# dask-core-2022.6.1   | 838 KB    |            |   0%
# dask-core-2022.6.1   | 838 KB    | ########## | 100%
# dask-core-2022.6.1   | 838 KB    | ########## | 100%
#
# typing-extensions-4. | 8 KB      |            |   0%
# typing-extensions-4. | 8 KB      | ########## | 100%
#
# zarr-2.13.3          | 141 KB    |            |   0%
# zarr-2.13.3          | 141 KB    | #1         |  11%
# zarr-2.13.3          | 141 KB    | ########## | 100%
# zarr-2.13.3          | 141 KB    | ########## | 100%
#
# napari-0.4.14        | 1.9 MB    |            |   0%
# napari-0.4.14        | 1.9 MB    |            |   1%
# napari-0.4.14        | 1.9 MB    | ###5       |  36%
# napari-0.4.14        | 1.9 MB    | #########3 |  93%
# napari-0.4.14        | 1.9 MB    | ########## | 100%
#
# freetype-py-2.3.0    | 58 KB     |            |   0%
# freetype-py-2.3.0    | 58 KB     | ##7        |  28%
# freetype-py-2.3.0    | 58 KB     | ########## | 100%
#
# lz4-4.0.0            | 80 KB     |            |   0%
# lz4-4.0.0            | 80 KB     | ##         |  20%
# lz4-4.0.0            | 80 KB     | ########## | 100%
#
# sphinx-5.3.0         | 1.6 MB    |            |   0%
# sphinx-5.3.0         | 1.6 MB    | ########## | 100%
# sphinx-5.3.0         | 1.6 MB    | ########## | 100%
#
# docutils-0.19        | 799 KB    |            |   0%
# docutils-0.19        | 799 KB    | ########## | 100%
# docutils-0.19        | 799 KB    | ########## | 100%
#
# fasteners-0.17.3     | 20 KB     |            |   0%
# fasteners-0.17.3     | 20 KB     | ########## | 100%
#
# msgpack-python-1.0.4 | 75 KB     |            |   0%
# msgpack-python-1.0.4 | 75 KB     | ##1        |  21%
# msgpack-python-1.0.4 | 75 KB     | ########## | 100%
#
# numcodecs-0.10.2     | 548 KB    |            |   0%
# numcodecs-0.10.2     | 548 KB    | 2          |   3%
# numcodecs-0.10.2     | 548 KB    | ##3        |  23%
# numcodecs-0.10.2     | 548 KB    | ####6      |  47%
# numcodecs-0.10.2     | 548 KB    | ######4    |  64%
# numcodecs-0.10.2     | 548 KB    | ########## | 100%
# numcodecs-0.10.2     | 548 KB    | ########## | 100%
#
# pep517-0.13.0        | 19 KB     |            |   0%
# pep517-0.13.0        | 19 KB     | ########6  |  86%
# pep517-0.13.0        | 19 KB     | ########## | 100%
#
# dask-2022.6.1        | 5 KB      |            |   0%
# dask-2022.6.1        | 5 KB      | ########## | 100%
#
# pytomlpp-1.0.9       | 162 KB    |            |   0%
# pytomlpp-1.0.9       | 162 KB    | 9          |  10%
# pytomlpp-1.0.9       | 162 KB    | #######8   |  79%
# pytomlpp-1.0.9       | 162 KB    | ########## | 100%
#
# pyqt-5.9.2           | 4.3 MB    |            |   0%
# pyqt-5.9.2           | 4.3 MB    |            |   0%
# pyqt-5.9.2           | 4.3 MB    | 3          |   4%
# pyqt-5.9.2           | 4.3 MB    | #4         |  15%
# pyqt-5.9.2           | 4.3 MB    | ###6       |  37%
# pyqt-5.9.2           | 4.3 MB    | #######4   |  74%
# pyqt-5.9.2           | 4.3 MB    | ########## | 100%
# pyqt-5.9.2           | 4.3 MB    | ########## | 100%
#
# napari-console-0.0.6 | 11 KB     |            |   0%
# napari-console-0.0.6 | 11 KB     | ########## | 100%
# napari-console-0.0.6 | 11 KB     | ########## | 100%
#
# shellingham-1.5.0    | 12 KB     |            |   0%
# shellingham-1.5.0    | 12 KB     | ########## | 100%
#
# commonmark-0.9.1     | 46 KB     |            |   0%
# commonmark-0.9.1     | 46 KB     | ########## | 100%
#
# pooch-1.6.0          | 44 KB     |            |   0%
# pooch-1.6.0          | 44 KB     | ########## | 100%
#
# pyopengl-3.1.6       | 867 KB    |            |   0%
# pyopengl-3.1.6       | 867 KB    | ########## | 100%
# pyopengl-3.1.6       | 867 KB    | ########## | 100%
#
# typer-0.7.0          | 56 KB     |            |   0%
# typer-0.7.0          | 56 KB     | ##8        |  28%
# typer-0.7.0          | 56 KB     | ########## | 100%
# typer-0.7.0          | 56 KB     | ########## | 100%
#
# kiwisolver-1.4.4     | 61 KB     |            |   0%
# kiwisolver-1.4.4     | 61 KB     | ########## | 100%
# kiwisolver-1.4.4     | 61 KB     | ########## | 100%
#
# fsspec-2022.11.0     | 96 KB     |            |   0%
# fsspec-2022.11.0     | 96 KB     | ########## | 100%
#
# rich-12.6.0          | 170 KB    |            |   0%
# rich-12.6.0          | 170 KB    | ########## | 100%
# rich-12.6.0          | 170 KB    | ########## | 100%
#
# numpydoc-1.5.0       | 46 KB     |            |   0%
# numpydoc-1.5.0       | 46 KB     | ########## | 100%
#
# sip-4.19.13          | 283 KB    |            |   0%
# sip-4.19.13          | 283 KB    | 5          |   6%
# sip-4.19.13          | 283 KB    | ####5      |  45%
# sip-4.19.13          | 283 KB    | ########## | 100%
# sip-4.19.13          | 283 KB    | ########## | 100%
#
# napari-svg-0.1.6     | 15 KB     |            |   0%
# napari-svg-0.1.6     | 15 KB     | ########## | 100%
# napari-svg-0.1.6     | 15 KB     | ########## | 100%
#
# yaml-0.2.5           | 62 KB     |            |   0%
# yaml-0.2.5           | 62 KB     | ########## | 100%
#
# future-0.18.2        | 356 KB    |            |   0%
# future-0.18.2        | 356 KB    | ########## | 100%
# future-0.18.2        | 356 KB    | ########## | 100%
#
# pint-0.20.1          | 207 KB    |            |   0%
# pint-0.20.1          | 207 KB    | 7          |   8%
# pint-0.20.1          | 207 KB    | ########## | 100%
# pint-0.20.1          | 207 KB    | ########## | 100%
#
# zict-2.2.0           | 20 KB     |            |   0%
# zict-2.2.0           | 20 KB     | ########## | 100%
#
# npe2-0.6.1           | 63 KB     |            |   0%
# npe2-0.6.1           | 63 KB     | ##5        |  25%
# npe2-0.6.1           | 63 KB     | ########## | 100%
#
# click-8.1.3          | 75 KB     |            |   0%
# click-8.1.3          | 75 KB     | ########## | 100%
#
# psygnal-0.3.5        | 515 KB    |            |   0%
# psygnal-0.3.5        | 515 KB    | 3          |   3%
# psygnal-0.3.5        | 515 KB    | ########## | 100%
# psygnal-0.3.5        | 515 KB    | ########## | 100%
#
# superqt-0.4.0        | 52 KB     |            |   0%
# superqt-0.4.0        | 52 KB     | ###        |  31%
# superqt-0.4.0        | 52 KB     | ########## | 100%
#
# magicgui-0.6.0       | 80 KB     |            |   0%
# magicgui-0.6.0       | 80 KB     | #9         |  20%
# magicgui-0.6.0       | 80 KB     | ########## | 100%
#
# qtconsole-base-5.4.0 | 91 KB     |            |   0%
# qtconsole-base-5.4.0 | 91 KB     | ########## | 100%
#
# pyyaml-6.0           | 154 KB    |            |   0%
# pyyaml-6.0           | 154 KB    | #          |  10%
# pyyaml-6.0           | 154 KB    | ########## | 100%
#
# imagesize-1.4.1      | 10 KB     |            |   0%
# imagesize-1.4.1      | 10 KB     | ########## | 100%
#
# locket-1.0.0         | 8 KB      |            |   0%
# locket-1.0.0         | 8 KB      | ########## | 100%
#
# bokeh-2.4.3          | 13.3 MB   |            |   0%
# bokeh-2.4.3          | 13.3 MB   | #3         |  14%
# bokeh-2.4.3          | 13.3 MB   | ####2      |  43%
# bokeh-2.4.3          | 13.3 MB   | ######7    |  68%
# bokeh-2.4.3          | 13.3 MB   | #########6 |  96%
# bokeh-2.4.3          | 13.3 MB   | ########## | 100%
#
# distributed-2022.6.1 | 731 KB    |            |   0%
# distributed-2022.6.1 | 731 KB    | ########## | 100%
# distributed-2022.6.1 | 731 KB    | ########## | 100%
#
# vispy-0.9.6          | 1.6 MB    |            |   0%
# vispy-0.9.6          | 1.6 MB    |            |   1%
# vispy-0.9.6          | 1.6 MB    | ###3       |  34%
# vispy-0.9.6          | 1.6 MB    | #########2 |  93%
# vispy-0.9.6          | 1.6 MB    | ########## | 100%
#
# wrapt-1.14.1         | 49 KB     |            |   0%
# wrapt-1.14.1         | 49 KB     | ###2       |  33%
# wrapt-1.14.1         | 49 KB     | ########## | 100%
#
# pydantic-1.9.2       | 1.6 MB    |            |   0%
# pydantic-1.9.2       | 1.6 MB    |            |   1%
# pydantic-1.9.2       | 1.6 MB    | ########## | 100%
# pydantic-1.9.2       | 1.6 MB    | ########## | 100%
#
# partd-1.3.0          | 18 KB     |            |   0%
# partd-1.3.0          | 18 KB     | ########## | 100%
#
# python-build-0.9.0   | 20 KB     |            |   0%
# python-build-0.9.0   | 20 KB     | ########1  |  82%
# python-build-0.9.0   | 20 KB     | ########## | 100%
#
# sphinxcontrib-serial | 27 KB     |            |   0%
# sphinxcontrib-serial | 27 KB     | ########## | 100%
# sphinxcontrib-serial | 27 KB     | ########## | 100%
#
# qtpy-2.3.0           | 50 KB     |            |   0%
# qtpy-2.3.0           | 50 KB     | ########## | 100%
# qtpy-2.3.0           | 50 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
## another library for napari
# !conda install -c anaconda pyqt -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - pyqt
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyqt-5.9.2                 |   py39hd77b12b_6         4.3 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following packages will be UPDATED:
#
#   openssl            conda-forge::openssl-1.1.1q-h8ffe710_0 --> pkgs/main::openssl-1.1.1s-h2bbff1b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.9.2~ --> anaconda::ca-certificates-2022.4.26-haa95532_0
#   certifi            conda-forge/noarch::certifi-2022.9.24~ --> anaconda/win-64::certifi-2022.6.15-py39haa95532_0
#   pyqt                                            pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
#
# pyqt-5.9.2           | 4.3 MB    |            |   0%
# pyqt-5.9.2           | 4.3 MB    |            |   0%
# pyqt-5.9.2           | 4.3 MB    | ######     |  61%
# pyqt-5.9.2           | 4.3 MB    | ########## | 100%
# pyqt-5.9.2           | 4.3 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
## Tensorflow needs numpy >=1.16.0 <= 1.23.0
# !conda uninstall numpy -y
# !conda install numpy == 1.23.0 -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   removed specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     attrs-22.1.0               |   py39haa95532_0          80 KB
#     cffi-1.15.1                |   py39h2bbff1b_0         223 KB
#     colorama-0.4.5             |   py39haa95532_0          28 KB
#     cryptography-38.0.1        |   py39h21b164f_0         1.1 MB
#     idna-3.4                   |   py39haa95532_0         109 KB
#     ipykernel-6.15.2           |   py39haa95532_0         187 KB
#     ipython-8.6.0              |   py39haa95532_0         1.1 MB
#     jinja2-3.1.2               |   py39haa95532_0         208 KB
#     jsonschema-4.16.0          |   py39haa95532_0         145 KB
#     jupyter_client-7.4.7       |   py39haa95532_0         224 KB
#     jupyter_core-4.11.2        |   py39haa95532_0         106 KB
#     jupyter_server-1.18.1      |   py39haa95532_0         408 KB
#     jupyterlab_server-2.15.2   |   py39haa95532_0          81 KB
#     libiconv-1.16              |       h2bbff1b_2         713 KB
#     libtiff-4.4.0              |       h8a3f274_2         1.1 MB
#     libwebp-1.2.4              |       h2bbff1b_0          76 KB
#     libwebp-base-1.2.4         |       h2bbff1b_0         327 KB
#     libxml2-2.9.12             |       h0ad7f3c_0         3.4 MB
#     libxslt-1.1.34             |       he774522_0         506 KB
#     lxml-4.8.0                 |   py39h1985fb9_0         1.1 MB
#     lz4-c-1.9.3                |       h2bbff1b_1         141 KB
#     matplotlib-inline-0.1.6    |   py39haa95532_0          18 KB
#     nbclassic-0.4.8            |   py39haa95532_0         7.7 MB
#     nbconvert-6.5.4            |   py39haa95532_0         582 KB
#     nbformat-5.5.0             |   py39haa95532_0         161 KB
#     notebook-6.5.2             |   py39haa95532_0         542 KB
#     notebook-shim-0.2.2        |   py39haa95532_0          22 KB
#     prometheus_client-0.14.1   |   py39haa95532_0          89 KB
#     psutil-5.9.0               |   py39h2bbff1b_0         364 KB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          49 KB
#     pyparsing-3.0.9            |   py39haa95532_0         153 KB
#     python-fastjsonschema-2.16.2|   py39haa95532_0         264 KB
#     pyzmq-23.2.0               |   py39hd77b12b_0         450 KB
#     requests-2.28.1            |   py39haa95532_0         100 KB
#     soupsieve-2.3.2.post1      |   py39haa95532_0          65 KB
#     tinycss2-1.2.1             |   py39haa95532_0          39 KB
#     tomli-2.0.1                |   py39haa95532_0          25 KB
#     tornado-6.2                |   py39h2bbff1b_0         668 KB
#     typing-extensions-4.3.0    |   py39haa95532_0           8 KB
#     typing_extensions-4.3.0    |   py39haa95532_0          44 KB
#     urllib3-1.26.12            |   py39haa95532_0         180 KB
#     winpty-0.4.3               |                4         1.1 MB
#     xz-5.2.6                   |       h8cc25b3_0         364 KB
#     zeromq-4.3.4               |       hd77b12b_0         9.0 MB
#     zstd-1.5.0                 |       h19a0ad4_1         1.4 MB
#     ------------------------------------------------------------
#                                            Total:        34.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   libiconv           pkgs/main/win-64::libiconv-1.16-h2bbff1b_2
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.2.4-h2bbff1b_0
#   libxml2            pkgs/main/win-64::libxml2-2.9.12-h0ad7f3c_0
#   libxslt            pkgs/main/win-64::libxslt-1.1.34-he774522_0
#   lxml               pkgs/main/win-64::lxml-4.8.0-py39h1985fb9_0
#
# The following packages will be REMOVED:
#
#   _tflow_select-2.3.0-mkl
#   abseil-cpp-20210324.2-h0e60522_0
#   absl-py-1.3.0-pyhd8ed1ab_0
#   aiohttp-3.8.1-py39hb82d6ee_1
#   aiosignal-1.3.1-pyhd8ed1ab_0
#   alabaster-0.7.12-py_0
#   appdirs-1.4.4-pyh9f0ad1d_0
#   asciitree-0.3.3-py_2
#   astor-0.8.1-pyh9f0ad1d_0
#   astunparse-1.6.3-pyhd8ed1ab_0
#   async-timeout-4.0.2-pyhd8ed1ab_0
#   backports-1.0-py_2
#   backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#   blas-1.0-mkl
#   blinker-1.5-pyhd8ed1ab_0
#   blosc-1.21.0-h19a0ad4_0
#   bokeh-2.4.3-pyhd8ed1ab_3
#   bottleneck-1.3.5-py39h080aedc_0
#   brotli-1.0.9-ha925a31_2
#   bzip2-1.0.8-he774522_0
#   cached-property-1.5.2-hd8ed1ab_1
#   cached_property-1.5.2-pyha770c72_1
#   cachetools-4.2.4-pyhd8ed1ab_0
#   cachey-0.2.1-pyh9f0ad1d_0
#   charls-2.2.0-h6c2663c_0
#   click-8.1.3-win_pyhd8ed1ab_2
#   cloudpickle-2.0.0-pyhd3eb1b0_0
#   commonmark-0.9.1-py_0
#   cycler-0.11.0-pyhd3eb1b0_0
#   cytoolz-0.11.0-py39h2bbff1b_0
#   dask-2022.6.1-pyhd8ed1ab_0
#   dask-core-2022.6.1-pyhd8ed1ab_0
#   dataclasses-0.8-pyhc8e2a94_3
#   distributed-2022.6.1-pyhd8ed1ab_0
#   docstring_parser-0.13-pyhd8ed1ab_0
#   docutils-0.19-py39hcbf5309_1
#   fasteners-0.17.3-pyhd8ed1ab_0
#   flatbuffers-2.0.7-h0e60522_0
#   flit-core-3.8.0-pyhd8ed1ab_0
#   fonttools-4.25.0-pyhd3eb1b0_0
#   freetype-py-2.3.0-pyhd8ed1ab_0
#   frozenlist-1.3.1-py39hb82d6ee_0
#   fsspec-2022.11.0-pyhd8ed1ab_0
#   future-0.18.2-pyhd8ed1ab_6
#   gast-0.4.0-pyh9f0ad1d_0
#   giflib-5.2.1-h62dcd97_0
#   google-auth-1.35.0-pyh6c4a22f_0
#   google-auth-oauthlib-0.4.6-pyhd8ed1ab_0
#   google-pasta-0.2.0-pyh8c360ce_0
#   grpcio-1.38.1-py39hb76b349_0
#   h5py-3.7.0-nompi_py39hd4deaf1_100
#   hdf5-1.12.1-nompi_h2a0e4a3_100
#   heapdict-1.0.1-py_0
#   hsluv-5.0.2-pyh44b312d_0
#   icc_rt-2019.0.0-h0cc432a_1
#   imagecodecs-2021.4.28-py39h5da4933_0
#   imageio-2.9.0-pyhd3eb1b0_0
#   imagesize-1.4.1-pyhd8ed1ab_0
#   importlib_resources-5.10.0-pyhd8ed1ab_0
#   intel-openmp-2021.4.0-haa95532_3556
#   joblib-1.2.0-pyhd8ed1ab_0
#   keras-preprocessing-1.1.2-pyhd8ed1ab_0
#   kiwisolver-1.4.4-py39h2e07f2f_0
#   krb5-1.19.3-h1176d77_0
#   lcms2-2.12-h83e58a3_0
#   libaec-1.0.4-h33f27b4_1
#   libblas-3.9.0-1_h8933c1f_netlib
#   libcblas-3.9.0-5_hd5c7e75_netlib
#   libcurl-7.79.1-h789b8ee_1
#   libprotobuf-3.14.0-h7755175_0
#   libssh2-1.10.0-h680486a_2
#   libzopfli-1.0.3-ha925a31_0
#   locket-1.0.0-pyhd8ed1ab_0
#   lz4-4.0.0-py39h0878066_2
#   m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gmp-6.1.0-2
#   m2w64-libwinpthread-git-5.0.0.4634.697f757-2
#   magicgui-0.6.0-pyhd8ed1ab_0
#   markdown-3.4.1-pyhd8ed1ab_0
#   matplotlib-3.5.1-py39haa95532_1
#   matplotlib-base-3.5.1-py39hd77b12b_1
#   mkl-2021.4.0-haa95532_640
#   mkl-service-2.4.0-py39h2bbff1b_0
#   mkl_fft-1.3.1-py39h277e83a_0
#   mkl_random-1.2.2-py39hf11a4ad_0
#   msgpack-python-1.0.4-py39h2e07f2f_0
#   msys2-conda-epoch-20160418-1
#   multidict-6.0.2-py39hb82d6ee_1
#   munkres-1.1.4-py_0
#   napari-0.4.14-pyhd8ed1ab_0
#   napari-console-0.0.6-pyhd8ed1ab_0
#   napari-plugin-engine-0.2.0-pyhd8ed1ab_2
#   napari-svg-0.1.6-pyhd8ed1ab_0
#   nbconvert-core-7.2.5-pyhd8ed1ab_0
#   nbconvert-pandoc-7.2.5-pyhd8ed1ab_0
#   networkx-2.7.1-pyhd3eb1b0_0
#   npe2-0.6.1-pyhd8ed1ab_1
#   numcodecs-0.10.2-py39h415ef7b_0
#   numexpr-2.8.4-py39h5b0cc5e_0
#   numpy-1.23.4-py39h3b20f71_0
#   numpy-base-1.23.4-py39h4da318b_0
#   numpydoc-1.5.0-pyhd8ed1ab_0
#   oauthlib-3.2.2-pyhd8ed1ab_0
#   openjpeg-2.4.0-h4fc8c34_0
#   opt_einsum-3.3.0-pyhd8ed1ab_1
#   pandas-1.5.1-py39hf11a4ad_0
#   pandoc-2.19.2-h57928b3_1
#   partd-1.3.0-pyhd8ed1ab_0
#   pep517-0.13.0-pyhd8ed1ab_0
#   pint-0.20.1-pyhd8ed1ab_0
#   pkgutil-resolve-name-1.3.10-pyhd8ed1ab_0
#   platformdirs-2.5.2-pyhd8ed1ab_1
#   pooch-1.6.0-pyhd8ed1ab_0
#   protobuf-3.14.0-py39h415ef7b_1
#   psygnal-0.3.5-py39h2e07f2f_0
#   pyasn1-0.4.8-py_0
#   pyasn1-modules-0.2.7-py_0
#   pydantic-1.9.2-py39hb82d6ee_0
#   pyjwt-2.6.0-pyhd8ed1ab_0
#   pyopengl-3.1.6-pyhd8ed1ab_1
#   python-build-0.9.0-pyhd8ed1ab_0
#   python-flatbuffers-1.12-pyhd8ed1ab_1
#   pytomlpp-1.0.9-py39h2e07f2f_0
#   pyu2f-0.1.5-pyhd8ed1ab_0
#   pywavelets-1.3.0-py39h2bbff1b_0
#   pyyaml-6.0-py39hb82d6ee_4
#   qtconsole-base-5.4.0-pyha770c72_0
#   qtpy-2.3.0-pyhd8ed1ab_0
#   requests-oauthlib-1.3.1-pyhd8ed1ab_0
#   rich-12.6.0-pyhd8ed1ab_0
#   rsa-4.9-pyhd8ed1ab_0
#   scikit-image-0.19.2-py39hf11a4ad_0
#   scikit-learn-1.1.2-py39hfd4428b_0
#   scipy-1.7.3-py39h0a974cb_0
#   shellingham-1.5.0-pyhd8ed1ab_0
#   sip-4.19.13-py39hd77b12b_0
#   snappy-1.1.9-h6c2663c_0
#   snowballstemmer-2.2.0-pyhd8ed1ab_0
#   sortedcontainers-2.4.0-pyhd8ed1ab_0
#   sphinx-5.3.0-pyhd8ed1ab_0
#   sphinxcontrib-applehelp-1.0.2-py_0
#   sphinxcontrib-devhelp-1.0.2-py_0
#   sphinxcontrib-htmlhelp-2.0.0-pyhd8ed1ab_0
#   sphinxcontrib-jsmath-1.0.1-py_0
#   sphinxcontrib-qthelp-1.0.3-py_0
#   sphinxcontrib-serializinghtml-1.1.5-pyhd8ed1ab_2
#   superqt-0.4.0-pyhd8ed1ab_0
#   tblib-1.7.0-pyhd8ed1ab_0
#   tensorboard-2.6.0-pyhd8ed1ab_1
#   tensorboard-data-server-0.6.0-py39hcbf5309_3
#   tensorboard-plugin-wit-1.8.1-pyhd8ed1ab_0
#   tensorflow-2.6.0-mkl_py39h31650da_0
#   tensorflow-base-2.6.0-mkl_py39h9201259_0
#   tensorflow-estimator-2.6.0-pyh7b7c402_0
#   termcolor-2.1.0-pyhd8ed1ab_0
#   threadpoolctl-3.1.0-pyh8a188c0_0
#   tifffile-2021.7.2-pyhd3eb1b0_2
#   toolz-0.11.2-pyhd3eb1b0_0
#   tqdm-4.64.1-pyhd8ed1ab_0
#   typer-0.7.0-pyhd8ed1ab_0
#   vispy-0.9.6-py39h5d4886f_1
#   werkzeug-2.2.2-pyhd8ed1ab_0
#   wrapt-1.14.1-py39hb82d6ee_0
#   yaml-0.2.5-h8ffe710_2
#   yarl-1.7.2-py39hb82d6ee_2
#   zarr-2.13.3-pyhd8ed1ab_0
#   zfp-0.5.5-hd77b12b_6
#   zict-2.2.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> pkgs/main::ca-certificates-2022.10.11-haa95532_0
#   certifi            anaconda::certifi-2022.6.15-py39haa95~ --> pkgs/main::certifi-2022.9.24-py39haa95532_0
#   cryptography       conda-forge::cryptography-37.0.4-py39~ --> pkgs/main::cryptography-38.0.1-py39h21b164f_0
#   json5               conda-forge::json5-0.9.5-pyh9f0ad1d_0 --> pkgs/main::json5-0.9.6-pyhd3eb1b0_0
#   lerc                      anaconda::lerc-2.2.1-hd77b12b_0 --> pkgs/main::lerc-3.0-hd77b12b_0
#   libdeflate            anaconda::libdeflate-1.7-h2bbff1b_5 --> pkgs/main::libdeflate-1.8-h2bbff1b_5
#   libtiff                anaconda::libtiff-4.2.0-hd0e1b90_0 --> pkgs/main::libtiff-4.4.0-h8a3f274_2
#   libwebp                anaconda::libwebp-1.2.2-h2bbff1b_0 --> pkgs/main::libwebp-1.2.4-h2bbff1b_0
#   pywinpty           conda-forge::pywinpty-0.5.7-py39hcbf5~ --> pkgs/main::pywinpty-2.0.2-py39h5da7b33_0
#   send2trash         conda-forge::send2trash-1.8.0-pyhd8ed~ --> pkgs/main::send2trash-1.8.0-pyhd3eb1b0_1
#   six                  conda-forge::six-1.16.0-pyh6c4a22f_0 --> pkgs/main::six-1.16.0-pyhd3eb1b0_1
#   terminado          conda-forge::terminado-0.9.4-py39hcbf~ --> pkgs/main::terminado-0.13.1-py39haa95532_0
#   urllib3            conda-forge/noarch::urllib3-1.26.11-p~ --> pkgs/main/win-64::urllib3-1.26.12-py39haa95532_0
#   wheel              conda-forge::wheel-0.35.1-pyh9f0ad1d_0 --> pkgs/main::wheel-0.37.1-pyhd3eb1b0_0
#   xz                          anaconda::xz-5.2.5-h8cc25b3_1 --> pkgs/main::xz-5.2.6-h8cc25b3_0
#   zstd                      anaconda::zstd-1.4.5-h04227a9_0 --> pkgs/main::zstd-1.5.0-h19a0ad4_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   anyio              conda-forge/noarch::anyio-3.6.2-pyhd8~ --> pkgs/main/win-64::anyio-3.5.0-py39haa95532_0
#   argon2-cffi        conda-forge::argon2-cffi-21.3.0-pyhd8~ --> pkgs/main::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ conda-forge::argon2-cffi-bindings-21.~ --> pkgs/main::argon2-cffi-bindings-21.2.0-py39h2bbff1b_0
#   asttokens          conda-forge::asttokens-2.1.0-pyhd8ed1~ --> pkgs/main::asttokens-2.0.5-pyhd3eb1b0_0
#   attrs              conda-forge/noarch::attrs-22.1.0-pyh7~ --> pkgs/main/win-64::attrs-22.1.0-py39haa95532_0
#   babel              conda-forge::babel-2.11.0-pyhd8ed1ab_0 --> pkgs/main::babel-2.9.1-pyhd3eb1b0_0
#   backcall           conda-forge::backcall-0.2.0-pyh9f0ad1~ --> pkgs/main::backcall-0.2.0-pyhd3eb1b0_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.~ --> pkgs/main/win-64::beautifulsoup4-4.11.1-py39haa95532_0
#   bleach             conda-forge::bleach-5.0.1-pyhd8ed1ab_0 --> pkgs/main::bleach-4.1.0-pyhd3eb1b0_0
#   brotlipy           conda-forge::brotlipy-0.7.0-py39hb82d~ --> pkgs/main::brotlipy-0.7.0-py39h2bbff1b_1003
#   cffi               conda-forge::cffi-1.15.1-py39h0878f49~ --> pkgs/main::cffi-1.15.1-py39h2bbff1b_0
#   charset-normalizer conda-forge::charset-normalizer-2.1.1~ --> pkgs/main::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   colorama           conda-forge/noarch::colorama-0.4.6-py~ --> pkgs/main/win-64::colorama-0.4.5-py39haa95532_0
#   debugpy            conda-forge::debugpy-1.6.3-py39h415ef~ --> pkgs/main::debugpy-1.5.1-py39hd77b12b_0
#   decorator          conda-forge::decorator-5.1.1-pyhd8ed1~ --> pkgs/main::decorator-5.1.1-pyhd3eb1b0_0
#   defusedxml         conda-forge::defusedxml-0.7.1-pyhd8ed~ --> pkgs/main::defusedxml-0.7.1-pyhd3eb1b0_0
#   entrypoints        conda-forge/noarch::entrypoints-0.4-p~ --> pkgs/main/win-64::entrypoints-0.4-py39haa95532_0
#   executing          conda-forge::executing-1.2.0-pyhd8ed1~ --> pkgs/main::executing-0.8.3-pyhd3eb1b0_0
#   freetype                                         anaconda --> pkgs/main
#   icu                      conda-forge::icu-68.2-h0e60522_0 --> pkgs/main::icu-68.1-h6c2663c_0
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1~ --> pkgs/main/win-64::idna-3.4-py39haa95532_0
#   importlib-metadata conda-forge/noarch::importlib-metadat~ --> pkgs/main/win-64::importlib-metadata-4.11.3-py39haa95532_0
#   ipykernel          conda-forge/noarch::ipykernel-6.17.1-~ --> pkgs/main/win-64::ipykernel-6.15.2-py39haa95532_0
#   ipython            conda-forge/noarch::ipython-8.6.0-pyh~ --> pkgs/main/win-64::ipython-8.6.0-py39haa95532_0
#   ipython_genutils   conda-forge::ipython_genutils-0.2.0-p~ --> pkgs/main::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   jedi               conda-forge/noarch::jedi-0.18.1-pyhd8~ --> pkgs/main/win-64::jedi-0.18.1-py39haa95532_1
#   jinja2             conda-forge/noarch::jinja2-3.1.2-pyhd~ --> pkgs/main/win-64::jinja2-3.1.2-py39haa95532_0
#   jpeg                      conda-forge::jpeg-9e-h8ffe710_2 --> pkgs/main::jpeg-9e-h2bbff1b_0
#   jsonschema         conda-forge/noarch::jsonschema-4.17.0~ --> pkgs/main/win-64::jsonschema-4.16.0-py39haa95532_0
#   jupyter_client     conda-forge/noarch::jupyter_client-7.~ --> pkgs/main/win-64::jupyter_client-7.4.7-py39haa95532_0
#   jupyter_core       conda-forge::jupyter_core-5.0.0-py39h~ --> pkgs/main::jupyter_core-4.11.2-py39haa95532_0
#   jupyter_server     conda-forge/noarch::jupyter_server-1.~ --> pkgs/main/win-64::jupyter_server-1.18.1-py39haa95532_0
#   jupyterlab_pygmen~ conda-forge::jupyterlab_pygments-0.2.~ --> pkgs/main::jupyterlab_pygments-0.1.2-py_0
#   jupyterlab_server  conda-forge/noarch::jupyterlab_server~ --> pkgs/main/win-64::jupyterlab_server-2.15.2-py39haa95532_0
#   libpng                                           anaconda --> pkgs/main
#   libsodium          conda-forge::libsodium-1.0.18-h8d1472~ --> pkgs/main::libsodium-1.0.18-h62dcd97_0
#   lz4-c                                            anaconda --> pkgs/main
#   markupsafe         conda-forge::markupsafe-2.1.1-py39hb8~ --> pkgs/main::markupsafe-2.1.1-py39h2bbff1b_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline~ --> pkgs/main/win-64::matplotlib-inline-0.1.6-py39haa95532_0
#   mistune            conda-forge/noarch::mistune-2.0.4-pyh~ --> pkgs/main/win-64::mistune-0.8.4-py39h2bbff1b_1000
#   nbclassic          conda-forge/noarch::nbclassic-0.4.8-p~ --> pkgs/main/win-64::nbclassic-0.4.8-py39haa95532_0
#   nbclient           conda-forge/noarch::nbclient-0.7.0-py~ --> pkgs/main/win-64::nbclient-0.5.13-py39haa95532_0
#   nbconvert          conda-forge/noarch::nbconvert-7.2.5-p~ --> pkgs/main/win-64::nbconvert-6.5.4-py39haa95532_0
#   nbformat           conda-forge/noarch::nbformat-5.7.0-py~ --> pkgs/main/win-64::nbformat-5.5.0-py39haa95532_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.~ --> pkgs/main/win-64::nest-asyncio-1.5.5-py39haa95532_0
#   notebook           conda-forge/noarch::notebook-6.5.2-py~ --> pkgs/main/win-64::notebook-6.5.2-py39haa95532_0
#   notebook-shim      conda-forge/noarch::notebook-shim-0.2~ --> pkgs/main/win-64::notebook-shim-0.2.2-py39haa95532_0
#   packaging          conda-forge::packaging-21.3-pyhd8ed1a~ --> pkgs/main::packaging-21.3-pyhd3eb1b0_0
#   pandocfilters      conda-forge::pandocfilters-1.5.0-pyhd~ --> pkgs/main::pandocfilters-1.5.0-pyhd3eb1b0_0
#   parso               conda-forge::parso-0.8.3-pyhd8ed1ab_0 --> pkgs/main::parso-0.8.3-pyhd3eb1b0_0
#   pickleshare        conda-forge::pickleshare-0.7.5-py_1003 --> pkgs/main::pickleshare-0.7.5-pyhd3eb1b0_1003
#   prometheus_client  conda-forge/noarch::prometheus_client~ --> pkgs/main/win-64::prometheus_client-0.14.1-py39haa95532_0
#   prompt-toolkit     conda-forge::prompt-toolkit-3.0.32-py~ --> pkgs/main::prompt-toolkit-3.0.20-pyhd3eb1b0_0
#   psutil             conda-forge::psutil-5.9.1-py39hb82d6e~ --> pkgs/main::psutil-5.9.0-py39h2bbff1b_0
#   pure_eval          conda-forge::pure_eval-0.2.2-pyhd8ed1~ --> pkgs/main::pure_eval-0.2.2-pyhd3eb1b0_0
#   pycparser          conda-forge::pycparser-2.21-pyhd8ed1a~ --> pkgs/main::pycparser-2.21-pyhd3eb1b0_0
#   pygments           conda-forge::pygments-2.13.0-pyhd8ed1~ --> pkgs/main::pygments-2.11.2-pyhd3eb1b0_0
#   pyopenssl          conda-forge::pyopenssl-22.0.0-pyhd8ed~ --> pkgs/main::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-p~ --> pkgs/main/win-64::pyparsing-3.0.9-py39haa95532_0
#   pyrsistent         conda-forge::pyrsistent-0.18.1-py39hb~ --> pkgs/main::pyrsistent-0.18.0-py39h196d8e1_0
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyh~ --> pkgs/main/win-64::pysocks-1.7.1-py39haa95532_0
#   python-dateutil    conda-forge::python-dateutil-2.8.2-py~ --> pkgs/main::python-dateutil-2.8.2-pyhd3eb1b0_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonsc~ --> pkgs/main/win-64::python-fastjsonschema-2.16.2-py39haa95532_0
#   pytz               conda-forge/noarch::pytz-2022.6-pyhd8~ --> pkgs/main/win-64::pytz-2022.1-py39haa95532_0
#   pywin32            conda-forge::pywin32-303-py39hb82d6ee~ --> pkgs/main::pywin32-302-py39h2bbff1b_2
#   pyzmq              conda-forge::pyzmq-23.2.1-py39he46f08~ --> pkgs/main::pyzmq-23.2.0-py39hd77b12b_0
#   requests           conda-forge/noarch::requests-2.28.1-p~ --> pkgs/main/win-64::requests-2.28.1-py39haa95532_0
#   sniffio            conda-forge/noarch::sniffio-1.3.0-pyh~ --> pkgs/main/win-64::sniffio-1.2.0-py39haa95532_1
#   soupsieve          conda-forge/noarch::soupsieve-2.3.2.p~ --> pkgs/main/win-64::soupsieve-2.3.2.post1-py39haa95532_0
#   stack_data         conda-forge::stack_data-0.6.1-pyhd8ed~ --> pkgs/main::stack_data-0.2.0-pyhd3eb1b0_0
#   tinycss2           conda-forge/noarch::tinycss2-1.2.1-py~ --> pkgs/main/win-64::tinycss2-1.2.1-py39haa95532_0
#   tomli              conda-forge/noarch::tomli-2.0.1-pyhd8~ --> pkgs/main/win-64::tomli-2.0.1-py39haa95532_0
#   tornado            conda-forge::tornado-6.2-py39hb82d6ee~ --> pkgs/main::tornado-6.2-py39h2bbff1b_0
#   traitlets          conda-forge::traitlets-5.5.0-pyhd8ed1~ --> pkgs/main::traitlets-5.1.1-pyhd3eb1b0_0
#   typing-extensions  conda-forge/noarch::typing-extensions~ --> pkgs/main/win-64::typing-extensions-4.3.0-py39haa95532_0
#   typing_extensions  conda-forge/noarch::typing_extensions~ --> pkgs/main/win-64::typing_extensions-4.3.0-py39haa95532_0
#   wcwidth            conda-forge::wcwidth-0.2.5-pyh9f0ad1d~ --> pkgs/main::wcwidth-0.2.5-pyhd3eb1b0_0
#   webencodings       conda-forge/noarch::webencodings-0.5.~ --> pkgs/main/win-64::webencodings-0.5.1-py39haa95532_1
#   websocket-client   conda-forge/noarch::websocket-client-~ --> pkgs/main/win-64::websocket-client-0.58.0-py39haa95532_4
#   win_inet_pton      conda-forge/noarch::win_inet_pton-1.1~ --> pkgs/main/win-64::win_inet_pton-1.1.0-py39haa95532_0
#   winpty                                        conda-forge --> pkgs/main
#   zeromq               conda-forge::zeromq-4.3.4-h0e60522_1 --> pkgs/main::zeromq-4.3.4-hd77b12b_0
#   zipp               conda-forge/noarch::zipp-3.10.0-pyhd8~ --> pkgs/main/win-64::zipp-3.8.0-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# libxml2-2.9.12       | 3.4 MB    |            |   0%
# libxml2-2.9.12       | 3.4 MB    |            |   0%
# libxml2-2.9.12       | 3.4 MB    | 8          |   8%
# libxml2-2.9.12       | 3.4 MB    | #4         |  15%
# libxml2-2.9.12       | 3.4 MB    | ##4        |  24%
# libxml2-2.9.12       | 3.4 MB    | ########3  |  83%
# libxml2-2.9.12       | 3.4 MB    | ########## | 100%
#
# nbformat-5.5.0       | 161 KB    |            |   0%
# nbformat-5.5.0       | 161 KB    | 9          |  10%
# nbformat-5.5.0       | 161 KB    | ########## | 100%
#
# jinja2-3.1.2         | 208 KB    |            |   0%
# jinja2-3.1.2         | 208 KB    | 7          |   8%
# jinja2-3.1.2         | 208 KB    | ########## | 100%
#
# nbconvert-6.5.4      | 582 KB    |            |   0%
# nbconvert-6.5.4      | 582 KB    | 2          |   3%
# nbconvert-6.5.4      | 582 KB    | ##1        |  22%
# nbconvert-6.5.4      | 582 KB    | ######     |  60%
# nbconvert-6.5.4      | 582 KB    | ########## | 100%
# nbconvert-6.5.4      | 582 KB    | ########## | 100%
#
# notebook-shim-0.2.2  | 22 KB     |            |   0%
# notebook-shim-0.2.2  | 22 KB     | #######3   |  73%
# notebook-shim-0.2.2  | 22 KB     | ########## | 100%
#
# pyopenssl-22.0.0     | 49 KB     |            |   0%
# pyopenssl-22.0.0     | 49 KB     | ###2       |  33%
# pyopenssl-22.0.0     | 49 KB     | ########## | 100%
#
# lxml-4.8.0           | 1.1 MB    |            |   0%
# lxml-4.8.0           | 1.1 MB    | 1          |   1%
# lxml-4.8.0           | 1.1 MB    | ########## | 100%
# lxml-4.8.0           | 1.1 MB    | ########## | 100%
#
# colorama-0.4.5       | 28 KB     |            |   0%
# colorama-0.4.5       | 28 KB     | #####8     |  58%
# colorama-0.4.5       | 28 KB     | ########## | 100%
#
# typing-extensions-4. | 8 KB      |            |   0%
# typing-extensions-4. | 8 KB      | ########## | 100%
# typing-extensions-4. | 8 KB      | ########## | 100%
#
# lz4-c-1.9.3          | 141 KB    |            |   0%
# lz4-c-1.9.3          | 141 KB    | #1         |  11%
# lz4-c-1.9.3          | 141 KB    | ########## | 100%
#
# libwebp-1.2.4        | 76 KB     |            |   0%
# libwebp-1.2.4        | 76 KB     | ##1        |  21%
# libwebp-1.2.4        | 76 KB     | ########## | 100%
#
# libtiff-4.4.0        | 1.1 MB    |            |   0%
# libtiff-4.4.0        | 1.1 MB    | 1          |   1%
# libtiff-4.4.0        | 1.1 MB    | #1         |  12%
# libtiff-4.4.0        | 1.1 MB    | ###2       |  32%
# libtiff-4.4.0        | 1.1 MB    | #####2     |  53%
# libtiff-4.4.0        | 1.1 MB    | ######8    |  69%
# libtiff-4.4.0        | 1.1 MB    | #########  |  90%
# libtiff-4.4.0        | 1.1 MB    | ########## | 100%
#
# matplotlib-inline-0. | 18 KB     |            |   0%
# matplotlib-inline-0. | 18 KB     | #########  |  91%
# matplotlib-inline-0. | 18 KB     | ########## | 100%
#
# jupyter_client-7.4.7 | 224 KB    |            |   0%
# jupyter_client-7.4.7 | 224 KB    | 7          |   7%
# jupyter_client-7.4.7 | 224 KB    | ########## | 100%
# jupyter_client-7.4.7 | 224 KB    | ########## | 100%
#
# idna-3.4             | 109 KB    |            |   0%
# idna-3.4             | 109 KB    | #4         |  15%
# idna-3.4             | 109 KB    | ########## | 100%
#
# requests-2.28.1      | 100 KB    |            |   0%
# requests-2.28.1      | 100 KB    | #6         |  16%
# requests-2.28.1      | 100 KB    | ########## | 100%
#
# psutil-5.9.0         | 364 KB    |            |   0%
# psutil-5.9.0         | 364 KB    | 4          |   4%
# psutil-5.9.0         | 364 KB    | ########## | 100%
# psutil-5.9.0         | 364 KB    | ########## | 100%
#
# cffi-1.15.1          | 223 KB    |            |   0%
# cffi-1.15.1          | 223 KB    | 7          |   7%
# cffi-1.15.1          | 223 KB    | ########## | 100%
# cffi-1.15.1          | 223 KB    | ########## | 100%
#
# attrs-22.1.0         | 80 KB     |            |   0%
# attrs-22.1.0         | 80 KB     | #9         |  20%
# attrs-22.1.0         | 80 KB     | ########## | 100%
#
# jupyter_core-4.11.2  | 106 KB    |            |   0%
# jupyter_core-4.11.2  | 106 KB    | #5         |  15%
# jupyter_core-4.11.2  | 106 KB    | ########## | 100%
# jupyter_core-4.11.2  | 106 KB    | ########## | 100%
#
# notebook-6.5.2       | 542 KB    |            |   0%
# notebook-6.5.2       | 542 KB    | 2          |   3%
# notebook-6.5.2       | 542 KB    | ####7      |  47%
# notebook-6.5.2       | 542 KB    | ########## | 100%
# notebook-6.5.2       | 542 KB    | ########## | 100%
#
# prometheus_client-0. | 89 KB     |            |   0%
# prometheus_client-0. | 89 KB     | #7         |  18%
# prometheus_client-0. | 89 KB     | ########## | 100%
#
# urllib3-1.26.12      | 180 KB    |            |   0%
# urllib3-1.26.12      | 180 KB    | 8          |   9%
# urllib3-1.26.12      | 180 KB    | ########## | 100%
# urllib3-1.26.12      | 180 KB    | ########## | 100%
#
# soupsieve-2.3.2.post | 65 KB     |            |   0%
# soupsieve-2.3.2.post | 65 KB     | ##4        |  24%
# soupsieve-2.3.2.post | 65 KB     | ########## | 100%
#
# libxslt-1.1.34       | 506 KB    |            |   0%
# libxslt-1.1.34       | 506 KB    | 3          |   3%
# libxslt-1.1.34       | 506 KB    | ###1       |  32%
# libxslt-1.1.34       | 506 KB    | #######5   |  76%
# libxslt-1.1.34       | 506 KB    | ########## | 100%
#
# pyparsing-3.0.9      | 153 KB    |            |   0%
# pyparsing-3.0.9      | 153 KB    | #          |  10%
# pyparsing-3.0.9      | 153 KB    | ########## | 100%
#
# libwebp-base-1.2.4   | 327 KB    |            |   0%
# libwebp-base-1.2.4   | 327 KB    | 4          |   5%
# libwebp-base-1.2.4   | 327 KB    | ######8    |  68%
# libwebp-base-1.2.4   | 327 KB    | ########## | 100%
#
# python-fastjsonschem | 264 KB    |            |   0%
# python-fastjsonschem | 264 KB    | 6          |   6%
# python-fastjsonschem | 264 KB    | #######2   |  73%
# python-fastjsonschem | 264 KB    | ########## | 100%
#
# cryptography-38.0.1  | 1.1 MB    |            |   0%
# cryptography-38.0.1  | 1.1 MB    | 1          |   1%
# cryptography-38.0.1  | 1.1 MB    | ########## | 100%
# cryptography-38.0.1  | 1.1 MB    | ########## | 100%
#
# tinycss2-1.2.1       | 39 KB     |            |   0%
# tinycss2-1.2.1       | 39 KB     | ####1      |  41%
# tinycss2-1.2.1       | 39 KB     | ########## | 100%
#
# ipykernel-6.15.2     | 187 KB    |            |   0%
# ipykernel-6.15.2     | 187 KB    | 8          |   9%
# ipykernel-6.15.2     | 187 KB    | ########## | 100%
# ipykernel-6.15.2     | 187 KB    | ########## | 100%
#
# tornado-6.2          | 668 KB    |            |   0%
# tornado-6.2          | 668 KB    | 2          |   2%
# tornado-6.2          | 668 KB    | ##8        |  29%
# tornado-6.2          | 668 KB    | #########  |  91%
# tornado-6.2          | 668 KB    | ########## | 100%
#
# pyzmq-23.2.0         | 450 KB    |            |   0%
# pyzmq-23.2.0         | 450 KB    | 3          |   4%
# pyzmq-23.2.0         | 450 KB    | ########## | 100%
# pyzmq-23.2.0         | 450 KB    | ########## | 100%
#
# tomli-2.0.1          | 25 KB     |            |   0%
# tomli-2.0.1          | 25 KB     | ######4    |  64%
# tomli-2.0.1          | 25 KB     | ########## | 100%
#
# zeromq-4.3.4         | 9.0 MB    |            |   0%
# zeromq-4.3.4         | 9.0 MB    |            |   0%
# zeromq-4.3.4         | 9.0 MB    | 8          |   9%
# zeromq-4.3.4         | 9.0 MB    | ##5        |  25%
# zeromq-4.3.4         | 9.0 MB    | #####      |  50%
# zeromq-4.3.4         | 9.0 MB    | #######7   |  77%
# zeromq-4.3.4         | 9.0 MB    | ########## | 100%
# zeromq-4.3.4         | 9.0 MB    | ########## | 100%
#
# ipython-8.6.0        | 1.1 MB    |            |   0%
# ipython-8.6.0        | 1.1 MB    | 1          |   1%
# ipython-8.6.0        | 1.1 MB    | ########## | 100%
# ipython-8.6.0        | 1.1 MB    | ########## | 100%
#
# jupyterlab_server-2. | 81 KB     |            |   0%
# jupyterlab_server-2. | 81 KB     | #9         |  20%
# jupyterlab_server-2. | 81 KB     | ########## | 100%
#
# xz-5.2.6             | 364 KB    |            |   0%
# xz-5.2.6             | 364 KB    | 4          |   4%
# xz-5.2.6             | 364 KB    | #####2     |  53%
# xz-5.2.6             | 364 KB    | ########## | 100%
# xz-5.2.6             | 364 KB    | ########## | 100%
#
# libiconv-1.16        | 713 KB    |            |   0%
# libiconv-1.16        | 713 KB    | 2          |   2%
# libiconv-1.16        | 713 KB    | ########## | 100%
# libiconv-1.16        | 713 KB    | ########## | 100%
#
# typing_extensions-4. | 44 KB     |            |   0%
# typing_extensions-4. | 44 KB     | ###6       |  37%
# typing_extensions-4. | 44 KB     | ########## | 100%
#
# winpty-0.4.3         | 1.1 MB    |            |   0%
# winpty-0.4.3         | 1.1 MB    | 1          |   1%
# winpty-0.4.3         | 1.1 MB    | ###6       |  36%
# winpty-0.4.3         | 1.1 MB    | ########## | 100%
# winpty-0.4.3         | 1.1 MB    | ########## | 100%
#
# zstd-1.5.0           | 1.4 MB    |            |   0%
# zstd-1.5.0           | 1.4 MB    | 1          |   1%
# zstd-1.5.0           | 1.4 MB    | ########## | 100%
# zstd-1.5.0           | 1.4 MB    | ########## | 100%
#
# jsonschema-4.16.0    | 145 KB    |            |   0%
# jsonschema-4.16.0    | 145 KB    | #1         |  11%
# jsonschema-4.16.0    | 145 KB    | ########## | 100%
#
# nbclassic-0.4.8      | 7.7 MB    |            |   0%
# nbclassic-0.4.8      | 7.7 MB    |            |   0%
# nbclassic-0.4.8      | 7.7 MB    | 2          |   2%
# nbclassic-0.4.8      | 7.7 MB    | 4          |   4%
# nbclassic-0.4.8      | 7.7 MB    | 5          |   6%
# nbclassic-0.4.8      | 7.7 MB    | 8          |   8%
# nbclassic-0.4.8      | 7.7 MB    | #1         |  11%
# nbclassic-0.4.8      | 7.7 MB    | #5         |  16%
# nbclassic-0.4.8      | 7.7 MB    | #7         |  18%
# nbclassic-0.4.8      | 7.7 MB    | ##1        |  21%
# nbclassic-0.4.8      | 7.7 MB    | ##3        |  23%
# nbclassic-0.4.8      | 7.7 MB    | ##6        |  26%
# nbclassic-0.4.8      | 7.7 MB    | ##8        |  29%
# nbclassic-0.4.8      | 7.7 MB    | ###1       |  32%
# nbclassic-0.4.8      | 7.7 MB    | ###4       |  35%
# nbclassic-0.4.8      | 7.7 MB    | ###7       |  37%
# nbclassic-0.4.8      | 7.7 MB    | ####       |  40%
# nbclassic-0.4.8      | 7.7 MB    | ####2      |  43%
# nbclassic-0.4.8      | 7.7 MB    | ####5      |  46%
# nbclassic-0.4.8      | 7.7 MB    | #####2     |  53%
# nbclassic-0.4.8      | 7.7 MB    | ######4    |  65%
# nbclassic-0.4.8      | 7.7 MB    | #########5 |  96%
# nbclassic-0.4.8      | 7.7 MB    | ########## | 100%
#
# jupyter_server-1.18. | 408 KB    |            |   0%
# jupyter_server-1.18. | 408 KB    | 3          |   4%
# jupyter_server-1.18. | 408 KB    | #####4     |  55%
# jupyter_server-1.18. | 408 KB    | ########## | 100%
# jupyter_server-1.18. | 408 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# DEBUG menuinst_win32:__init__(196): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\ProgramData\Anaconda3\envs\entorno_curso', env_name: 'entorno_curso', mode: 'system', used_mode: 'system'
# DEBUG menuinst_win32:create(320): Shortcut cmd is C:\ProgramData\Anaconda3\python.exe, args are ['C:\\ProgramData\\Anaconda3\\cwp.py', 'C:\\ProgramData\\Anaconda3\\envs\\entorno_curso', 'C:\\ProgramData\\Anaconda3\\envs\\entorno_curso\\python.exe', 'C:\\ProgramData\\Anaconda3\\envs\\entorno_curso\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
#
# CondaValueError: invalid package specification: ==

# %%
## Tensorflow, deep learning
# !conda install -c conda-forge tensorflow -y

#Check install
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
## Keras, easy deep learning, works on top of Tensorflow
# !conda install -c conda-forge keras -y

from tensorflow import keras
keras.__version__
# Out:
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     keras-2.6.0                |     pyhd8ed1ab_1         822 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         822 KB
#
# The following NEW packages will be INSTALLED:
#
#   keras              conda-forge/noarch::keras-2.6.0-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages
#
# keras-2.6.0          | 822 KB    |            |   0%
# keras-2.6.0          | 822 KB    | 1          |   2%
# keras-2.6.0          | 822 KB    | ########## | 100%
# keras-2.6.0          | 822 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# '2.6.0'

# %%
## Matplotlib Basic Image visualization library
# !conda install -c anaconda matplotlib -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3\envs\entorno_curso
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     kiwisolver-1.4.2           |   py39hd77b12b_0          65 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:          65 KB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             anaconda/win-64::brotli-1.0.9-ha925a31_2
#   cycler             anaconda/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          anaconda/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   kiwisolver         anaconda/win-64::kiwisolver-1.4.2-py39hd77b12b_0
#   matplotlib         anaconda/win-64::matplotlib-3.5.1-py39haa95532_1
#   matplotlib-base    anaconda/win-64::matplotlib-base-3.5.1-py39hd77b12b_1
#   munkres            anaconda/noarch::munkres-1.1.4-py_0
#
# The following packages will be UPDATED:
#
#   openssl            conda-forge::openssl-1.1.1q-h8ffe710_0 --> pkgs/main::openssl-1.1.1s-h2bbff1b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.9.2~ --> anaconda::ca-certificates-2022.4.26-haa95532_0
#   certifi            conda-forge/noarch::certifi-2022.9.24~ --> anaconda/win-64::certifi-2022.6.15-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# kiwisolver-1.4.2     | 65 KB     |            |   0%
# kiwisolver-1.4.2     | 65 KB     | ##4        |  25%
# kiwisolver-1.4.2     | 65 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Rolling back transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# ERROR conda.core.link:_execute(701): An error occurred while installing package 'defaults::openssl-1.1.1s-h2bbff1b_0'.
#
# [Errno 13] Permission denied: 'C:\\ProgramData\\Anaconda3\\envs\\entorno_curso\\Library\\bin\\libcrypto-1_1-x64.dll'
# ()
